# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder
from matplotlib import pyplot as plt

# data = pd.read_csv('GDPlist.csv',encoding='ISO-8859-1')
# data

# %%
#Tạo dữ liệu nhân tạo
y1 = np.random.normal(200, 30, size = 100)
y2 = np.random.normal(100, 70, size = 100)
data = pd.DataFrame({'y1': y1, 'y2': y2, 'date': pd.date_range('1/1/2021', periods=100)})
data
# Out:
#             y1          y2       date
# 0   201.131298   56.653294 2021-01-01
# 1   235.227548  191.302028 2021-01-02
# 2   207.988780  102.523832 2021-01-03
# 3   209.023823   -8.665080 2021-01-04
# 4   174.941227   98.171623 2021-01-05
# ..         ...         ...        ...
# 95  236.522757  117.507070 2021-04-06
# 96  197.756631  181.970340 2021-04-07
# 97  205.209305   -2.516515 2021-04-08
# 98  215.836791  222.511497 2021-04-09
# 99  196.930903   70.184293 2021-04-10
#
# [100 rows x 3 columns]

# %%
plt.plot(data.index,data.loc[:,'y1'],'r',label='y1')
plt.plot(data.index,data.loc[:,'y2'],'b',label='y2')
plt.title('Đồ Thị phân bố normal')
plt.xlabel('index')
plt.ylabel('dao động')
plt.legend()
plt.show()

# %%
#Tạo dữ liệu nhân tạo
y3 = np.random.normal(200, 30, size = 100)
y4 = np.random.normal(1000, 200, size = 100)
data = pd.DataFrame({'y3': y3, 'y4': y4, 'date': pd.date_range('1/1/2021', periods=100)})
data
plt.show()

# %%
#Tạo dữ liệu
x = ['Day 1','Day 2','Day 3','Day 4','Day 5','Day 6','Day 7','Day 8','Day 9','Day 10']
y1 = [12.2, 16.3, 20.5, 25.4, 31.2, 24.2, 18, 13.5, 17.1, 21.7]
y2 = [20.3, 27.6, 31.4, 33.7, 39.2, 33.4, 29.2, 25.7, 31.2, 36]
y3 = [16.3, 17.6, 24.4, 26.7, 33.2, 29.4, 27.2, 24.7, 27.2, 32]
data2 = pd.DataFrame({'x':x,'y1':y1,'y2':y2,'y3':y3})
data2
# Out:
#         x    y1    y2    y3
# 0   Day 1  12.2  20.3  16.3
# 1   Day 2  16.3  27.6  17.6
# 2   Day 3  20.5  31.4  24.4
# 3   Day 4  25.4  33.7  26.7
# 4   Day 5  31.2  39.2  33.2
# 5   Day 6  24.2  33.4  29.4
# 6   Day 7  18.0  29.2  27.2
# 7   Day 8  13.5  25.7  24.7
# 8   Day 9  17.1  31.2  27.2
# 9  Day 10  21.7  36.0  32.0

# %%
#Tạo Figure và Subplot (các axes = ax)
fig1, ax = plt.subplots(3,1)
ax[0].plot(data2['x'], data2['y1'], 'r', label='y1')
ax[1].plot(data2['x'], data2['y2'], 'b', label='y2')
ax[2].plot(data2['x'], data2['y3'], 'g', label='y3')

ax[0].set_title('Giá các mặt hàng')
ax[2].set_xlabel('Ngày')
ax[1].set_ylabel('Giá trị dầu')
ax[0].set_ylabel('Giá vàng')
ax[2].set_ylabel('Giá đôla')

ax[0].set_xticklabels([])
ax[1].set_xticklabels([])

ax[0].tick_params(axis='y', size = 8)
ax[1].tick_params(axis='y', size = 8)
ax[2].tick_params(axis='y', size = 8)

ax[0].tick_params(axis='x', size = 2)
ax[1].tick_params(axis='x', size = 2)
ax[2].tick_params(axis='x', size = 8)

# ax[0].set_xticks([]) #Remove tick
# ax[1].set_xticks([]) #Remove tick
plt.tight_layout(pad = 0) #Set margin between subplots
plt.show()

# %%
#Tạo dữ liệu nhân tạo
y1 = np.random.normal(100, 30, size = 100)
y2 = np.random.normal(100, 70, size = 100)
y3 = np.random.normal(200, 30, size = 100)
y4 = np.random.normal(1000, 200, size = 100)
data3 = pd.DataFrame({'y1':y1, 'y2':y2, 'y3': y3, 'y4': y4})
data3
# Out:
#             y1          y2          y3           y4
# 0    95.864605  272.994302  187.384282   887.161806
# 1    69.267271   17.478201  172.027858  1062.868724
# 2   119.224592  -57.653666  177.887313   715.800287
# 3   131.445539  161.539479  185.568295   950.838601
# 4   123.486634  -43.788747  201.107661  1445.202064
# ..         ...         ...         ...          ...
# 95   86.821500  114.689729  195.775388  1232.378452
# 96  103.323268  100.455159  184.583577   971.280406
# 97  106.745475   31.514215  152.138358  1092.150186
# 98  136.850079  111.069900  202.379819  1044.402934
# 99  131.602183  -16.624199  241.745983   997.172983
#
# [100 rows x 4 columns]

# %%
# Vẽ đồ thị 2x2
fig2, ax2 = plt.subplots(2,2,sharex=True)
# print(ax2[0])
# print(fig2)
ax2[0][0].plot(data3.index,data3['y1'],'r',label='y1')
ax2[0][1].plot(data3.index,data3['y2'],'g',label='y2')
ax2[1][0].plot(data3.index,data3['y3'],'b',label='y3')
ax2[1][1].plot(data3.index,data3['y4'],'y',label='y4')

ax2[0][0].set_title('Vi du 3')
# Out:
# Text(0.5, 1.0, 'Vi du 3')
